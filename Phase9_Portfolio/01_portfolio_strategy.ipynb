# %%
# PHASE 9 — PORTFOLIO & CARRIÈRE
# Transformer tes compétences en opportunités concrètes

print("=" * 60)
print("BILAN DE COMPÉTENCES — AI/ML ENGINEER")
print("=" * 60)

competences = {
    "Mathématiques": [
        "Algèbre linéaire (vecteurs, matrices, PCA)",
        "Calcul différentiel (dérivées, gradient, backprop)",
        "Probabilités et statistiques (Bayes, distributions)",
        "Théorie de l'information (entropie, cross-entropy)"
    ],
    "Python": [
        "Python complet (POO, décorateurs, générateurs)",
        "NumPy, Pandas, Matplotlib, Seaborn, Plotly",
        "Modules et packages personnalisés"
    ],
    "Machine Learning": [
        "Régression (Linear, Ridge, Lasso, ElasticNet)",
        "Classification (Logistic, SVM, KNN, Decision Tree)",
        "Ensemble (Random Forest, XGBoost, LightGBM)",
        "Clustering (K-Means, DBSCAN)",
        "Réduction de dimension (PCA, t-SNE)",
        "Hyperparameter Tuning (GridSearch, Optuna)"
    ],
    "Deep Learning": [
        "PyTorch (tenseurs, autograd, boucle d'entraînement)",
        "MLP, CNN, LSTM",
        "Transfer Learning (ResNet18)",
        "Data Augmentation",
        "Batch Normalization, fonctions d'activation"
    ],
    "NLP": [
        "Preprocessing, TF-IDF, Word Embeddings",
        "Hugging Face (DistilBERT, NER, Sentiment)",
        "Fine-tuning de modèles pré-entraînés",
        "Summarization automatique"
    ],
    "MLOps": [
        "FastAPI (API de prédiction complète)",
        "MLflow (tracking d'expériences)",
        "Docker (containerisation)",
        "GitHub Actions (CI/CD)",
        "Pytest (tests unitaires)"
    ]
}

for domaine, skills in competences.items():
    print(f"\n{'─'*40}")
    print(f"  {domaine}")
    print(f"{'─'*40}")
    for skill in skills:
        print(f"  ✅ {skill}")

print("\n" + "=" * 60)
print(f"Total : {sum(len(v) for v in competences.values())} compétences acquises")
print("=" * 60)
# Out:
# ...
# BILAN DE COMPÉTENCES — AI/ML ENGINEER
# ...
#
# ────────────────────────────────────────
#   Mathématiques
# ────────────────────────────────────────
#   ✅ Algèbre linéaire (vecteurs, matrices, PCA)
#   ✅ Calcul différentiel (dérivées, gradient, backprop)
#   ✅ Probabilités et statistiques (Bayes, distributions)
#   ✅ Théorie de l'information (entropie, cross-entropy)
#
# ────────────────────────────────────────
#   Python
# ────────────────────────────────────────
#   ✅ Python complet (POO, décorateurs, générateurs)
#   ✅ NumPy, Pandas, Matplotlib, Seaborn, Plotly
#   ✅ Modules et packages personnalisés
#
# ────────────────────────────────────────
#   Machine Learning
# ────────────────────────────────────────
#   ✅ Régression (Linear, Ridge, Lasso, ElasticNet)
#   ✅ Classification (Logistic, SVM, KNN, Decision Tree)
#   ✅ Ensemble (Random Forest, XGBoost, LightGBM)
#   ✅ Clustering (K-Means, DBSCAN)
#   ✅ Réduction de dimension (PCA, t-SNE)
# ...

# %%
# LES 10 PROJETS PORTFOLIO ESSENTIELS
# Ces projets démontrent tes compétences de façon concrète

projets = [
    {
        "niveau": "Débutant",
        "titre": "Analyse Titanic",
        "description": "Classification + visualisation complète",
        "skills": ["Pandas", "Seaborn", "Logistic Regression", "Random Forest"],
        "dataset": "kaggle.com/c/titanic",
        "duree": "3-5 jours"
    },
    {
        "niveau": "Débutant",
        "titre": "Prédicteur de Prix Immobiliers",
        "description": "Régression + feature engineering",
        "skills": ["Ridge/Lasso", "XGBoost", "Feature Engineering", "Optuna"],
        "dataset": "kaggle.com/c/house-prices-advanced-regression-techniques",
        "duree": "5-7 jours"
    },
    {
        "niveau": "Débutant",
        "titre": "Détecteur de Spam",
        "description": "NLP classique + ML",
        "skills": ["TF-IDF", "Naive Bayes", "Logistic Regression", "Pipeline"],
        "dataset": "SMS Spam Collection",
        "duree": "3-4 jours"
    },
    {
        "niveau": "Intermédiaire",
        "titre": "Classificateur d'Images Custom",
        "description": "CNN + Transfer Learning sur tes propres données",
        "skills": ["PyTorch", "ResNet18", "Data Augmentation", "Fine-tuning"],
        "dataset": "Tes propres images (photos Madagascar ?)",
        "duree": "7-10 jours"
    },
    {
        "niveau": "Intermédiaire",
        "titre": "Analyse de Sentiments Multi-langues",
        "description": "Hugging Face + Fine-tuning en malgache/français",
        "skills": ["DistilBERT", "Fine-tuning", "Hugging Face", "NLP"],
        "dataset": "Twitter/Facebook data",
        "duree": "7-10 jours"
    },
    {
        "niveau": "Intermédiaire",
        "titre": "Prévision Séries Temporelles",
        "description": "LSTM sur données réelles (météo, prix vanille)",
        "skills": ["LSTM", "PyTorch", "Time Series", "Feature Engineering"],
        "dataset": "Données météo Madagascar / Prix vanille",
        "duree": "7-10 jours"
    },
    {
        "niveau": "Avancé",
        "titre": "Système de Recommandation",
        "description": "Collaborative filtering + API déployée",
        "skills": ["Matrix Factorization", "FastAPI", "Docker", "MLflow"],
        "dataset": "MovieLens / produits e-commerce",
        "duree": "10-14 jours"
    },
    {
        "niveau": "Avancé",
        "titre": "Détecteur d'Objets Custom",
        "description": "YOLOv8 fine-tuné sur tes données",
        "skills": ["YOLOv8", "Transfer Learning", "Computer Vision", "Docker"],
        "dataset": "Tes propres photos",
        "duree": "10-14 jours"
    },
    {
        "niveau": "Avancé",
        "titre": "Chatbot RAG pour Transit Bongout",
        "description": "LangChain + base de connaissances douanières",
        "skills": ["LangChain", "RAG", "FastAPI", "Docker", "Claude API"],
        "dataset": "Documents douaniers Madagascar",
        "duree": "14-21 jours"
    },
    {
        "niveau": "Signature",
        "titre": "Barakah Market Intelligence",
        "description": "Recommandation produits + détection fraude + chatbot",
        "skills": ["Tout le stack ML/AI", "FastAPI", "Docker", "MLflow"],
        "dataset": "Données Barakah Market",
        "duree": "21-30 jours"
    }
]

print("=" * 65)
print("LES 10 PROJETS PORTFOLIO ESSENTIELS")
print("=" * 65)

niveaux_couleurs = {
    "Débutant": "🟢",
    "Intermédiaire": "🟡", 
    "Avancé": "🔴",
    "Signature": "⭐"
}

for i, projet in enumerate(projets, 1):
    emoji = niveaux_couleurs[projet["niveau"]]
    print(f"\n{emoji} PROJET {i} — {projet['titre']}")
    print(f"   Niveau    : {projet['niveau']}")
    print(f"   Objectif  : {projet['description']}")
    print(f"   Skills    : {', '.join(projet['skills'])}")
    print(f"   Dataset   : {projet['dataset']}")
    print(f"   Durée     : {projet['duree']}")

print("\n" + "=" * 65)
print("CONSEIL : Commence par les projets Débutant sur Kaggle")
print("puis progresse vers les projets Signature.")
print("=" * 65)
# Out:
# ...
# LES 10 PROJETS PORTFOLIO ESSENTIELS
# ...
#
# 🟢 PROJET 1 — Analyse Titanic
#    Niveau    : Débutant
#    Objectif  : Classification + visualisation complète
#    Skills    : Pandas, Seaborn, Logistic Regression, Random Forest
#    Dataset   : kaggle.com/c/titanic
#    Durée     : 3-5 jours
#
# 🟢 PROJET 2 — Prédicteur de Prix Immobiliers
#    Niveau    : Débutant
#    Objectif  : Régression + feature engineering
#    Skills    : Ridge/Lasso, XGBoost, Feature Engineering, Optuna
#    Dataset   : kaggle.com/c/house-prices-advanced-regression-techniques
#    Durée     : 5-7 jours
#
# 🟢 PROJET 3 — Détecteur de Spam
#    Niveau    : Débutant
#    Objectif  : NLP classique + ML
#    Skills    : TF-IDF, Naive Bayes, Logistic Regression, Pipeline
#    Dataset   : SMS Spam Collection
#    Durée     : 3-4 jours
#
# 🟡 PROJET 4 — Classificateur d'Images Custom
#    Niveau    : Intermédiaire
#    Objectif  : CNN + Transfer Learning sur tes propres données
# ...

# %%
# PLAN DE CARRIÈRE — Revenus et opportunités

print("=" * 60)
print("PLAN DE CARRIÈRE — AI/ML ENGINEER")
print("=" * 60)

print("""
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
MOIS 1-3 : CONSTRUIRE LE PORTFOLIO
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
Actions :
  ✅ Faire les 3 projets Débutant (Titanic, Prix, Spam)
  ✅ Publier sur GitHub avec README détaillé
  ✅ Créer un compte Kaggle et participer
  ✅ Créer profil LinkedIn optimisé
  ✅ Écrire 3 articles Medium sur tes projets

Objectif : 3 projets GitHub + 1 médaille Kaggle

━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
MOIS 4-6 : PREMIERS CLIENTS FREELANCE
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
Plateformes :
  • Upwork    → profil AI/ML Engineer
  • Malt      → marché français/européen
  • Toptal    → premium, bien payé
  • LinkedIn  → prospection directe

Tarifs débutant :
  • $25-40/heure sur Upwork
  • $50-80/heure sur Malt (Europe)
  
Revenus estimés (10h/semaine) :
  • Mois 4 : $500-800 (premiers clients)
  • Mois 5 : $1000-1500
  • Mois 6 : $1500-2500

━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
MOIS 7-12 : MONTÉE EN PUISSANCE
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
Actions :
  ✅ Projets Intermédiaires + Avancés
  ✅ Spécialisation (NLP ou Computer Vision)
  ✅ Augmenter les tarifs ($60-100/heure)
  ✅ Clients récurrents

Revenus estimés :
  • $3000-5000/mois freelance
  • OU poste salarié $60k-90k/an

━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
MARCHÉ MADAGASCAR — OPPORTUNITÉS UNIQUES
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
Tu es dans une position unique :
  ✅ Compétences AI/ML niveau international
  ✅ Connaissance du marché malgache
  ✅ Réseau local (Transit Bongout)
  ✅ Vision des besoins locaux

Projets à fort impact Madagascar :
  1. Barakah Market → e-commerce halal IA
  2. Quran App → NLP en malgache  
  3. Transit Bongout → IA pour la douane
  4. Chatbot en malgache → premier sur le marché
  5. Détection fraude → banques malgaches

Revenue potentiel Madagascar :
  • Consulting local : $500-2000/projet
  • SaaS AI : $200-1000/mois par client
  • Formation AI : $100-500/session
""")

print("=" * 60)
print("PROCHAINES ÉTAPES IMMÉDIATES")
print("=" * 60)
print("""
Cette semaine :
  1. Créer compte GitHub public
  2. Créer compte Kaggle
  3. Commencer Projet 1 (Titanic)
  4. Obtenir clé API Anthropic (console.anthropic.com)
  5. Créer profil LinkedIn optimisé

Ce mois :
  1. Finir les 3 projets Débutant
  2. Publier sur GitHub avec beau README
  3. Écrire 1 article Medium
  4. S'inscrire sur Upwork/Malt
""")
# Out:
# ...
# PLAN DE CARRIÈRE — AI/ML ENGINEER
# ...
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# MOIS 1-3 : CONSTRUIRE LE PORTFOLIO
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Actions :
#   ✅ Faire les 3 projets Débutant (Titanic, Prix, Spam)
#   ✅ Publier sur GitHub avec README détaillé
#   ✅ Créer un compte Kaggle et participer
#   ✅ Créer profil LinkedIn optimisé
#   ✅ Écrire 3 articles Medium sur tes projets
#
# Objectif : 3 projets GitHub + 1 médaille Kaggle
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# MOIS 4-6 : PREMIERS CLIENTS FREELANCE
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Plateformes :
#   • Upwork    → profil AI/ML Engineer
#   • Malt      → marché français/européen
#   • Toptal    → premium, bien payé
#   • LinkedIn  → prospection directe
#
# Tarifs débutant :
#   • $25-40/heure sur Upwork
#   • $50-80/heure sur Malt (Europe)
#
# Revenus estimés (10h/semaine) :
#   • Mois 4 : $500-800 (premiers clients)
#   • Mois 5 : $1000-1500
#   • Mois 6 : $1500-2500
#
# ...
